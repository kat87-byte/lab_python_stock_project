# %%
# !pip install pandas
# !pip install ipython-sql prettytable 

import prettytable

prettytable.DEFAULT = 'DEFAULT'
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 125.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 174.4 MB/s eta 0:00:00
# ...

# %%
# %load_ext sql

# %%
import sqlite3

# %%
import csv, sqlite3

# %%
con = sqlite3.connect("ChicagoCensusData.db")
cur = con.cursor()

# %%
# %sql sqlite:///ChicagoCensusData.db

# %%
con = sqlite3.connect("ChicagoPublicSchools.db")
cur = con.cursor()

# %%
# %sql sqlite:///ChicagoPublicSchools.db

# %%
con = sqlite3.connect("ChicagoCrimeData.db")
cur = con.cursor()

# %%
# %sql sqlite:///ChicagoCrimeData.db

# %%
import pandas

url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv'
df = pandas.read_csv(url)

# %%
df.to_sql("ChicagoCensusData", con, if_exists='replace', index=False, method="multi")
# Out:
# 78

# %%
df.to_sql("ChicagoPublicSchools", con, if_exists='replace', index=False, method="multi")
# Out:
# 78

# %%
df.to_sql("ChicagoCrimeData", con, if_exists='replace', index=False, method="multi")
# Out:
# 78

# %%
con = sqlite3.connect("ChicagoPublicSchools.db")
cur = con.cursor()

# %%
# %sql sqlite:///ChicagoPublicSchools.db

# %%
import pandas

url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv'
df = pandas.read_csv(url)

# %%
df.to_sql("ChicagoPublicSchools", con, if_exists='replace', index=False, method="multi")
# Out:
# 566

# %%
con = sqlite3.connect("ChicagoCrimeData.db")
cur = con.cursor()

# %%
# %sql sqlite:///ChicagoCrimeData.db

# %%
import pandas

url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv'
df = pandas.read_csv(url)

# %%
df.to_sql("ChicagoCrimeData", con, if_exists='replace', index=False, method="multi")
# Out:
# 533

# %%
# %sql SELECT MAX(total_number_of_crimes) FROM ChicagoCrimeData
# Out:
#    sqlite:///ChicagoCensusData.db
#  * sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# (sqlite3.OperationalError) no such column: total_number_of_crimes
# [SQL: SELECT MAX(total_number_of_crimes) FROM ChicagoCrimeData]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql SELECT * FROM ChicagoCrimeData LIMIT 5;
# Out:
#    sqlite:///ChicagoCensusData.db
#  * sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [(3512276, 'HK587712', '2004-08-28', '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 0, 0, 911, 9, 14.0, 58.0, '6', 1155838.0, 1873050.0, 2004, 41.8074405, -87.70395585, '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', '2004-06-26', '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 0, 0, 1112, 11, 27.0, 23.0, '6', 1152206.0, 1906127.0, 2004, 41.89827996, -87.71640551, '(41.898279962, -87.716405505)'),
#  (8002131, 'HT233595', '2011-04-04', '043XX S WABASH AVE', '820', 'THEFT', '$500 AND UNDER', 'NURSING HOME/RETIREMENT HOME', 0, 0, 221, 2, 3.0, 38.0, '6', 1177436.0, 1876313.0, 2011, 41.81593313, -87.62464213, '(41.815933131, -87.624642127)'),
# ...

# %%
# %sql SELECT MAX(case_number) FROM ChicagoCrimeData
# Out:
#    sqlite:///ChicagoCensusData.db
#  * sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [('JB213238',)]

# %%
# %sql SELECT COUNT(case_number) FROM ChicagoCrimeData;
# Out:
#    sqlite:///ChicagoCensusData.db
#  * sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [(533,)]

# %%
# %sql SELECT community_area_name, community_area_number, per_capita_income FROM ChicagoCensusData WHERE per_capita_income < 11000;
# Out:
#    sqlite:///ChicagoCensusData.db
#  * sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [('West Garfield Park', 26.0, 10934),
#  ('South Lawndale', 30.0, 10402),
#  ('Fuller Park', 37.0, 10432),
#  ('Riverdale', 54.0, 8201)]

# %%
# %sql SELECT * FROM ChicagoCensusData LIMIT 5
# Out:
#    sqlite:///ChicagoCensusData.db
#  * sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [(1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0),
#  (3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0),
#  (4.0, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17.0),
#  (5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0)]

# %%
# %sql SELECT case_number FROM ChicagoCrimeData WHERE description LIKE '%MINOR%' OR primary_type LIKE '%MINOR%';
# Out:
#    sqlite:///ChicagoCensusData.db
#  * sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [('HL266884',), ('HK238408',)]

# %%
# %sql SELECT * FROM ChicagoCrimeData WHERE primary_type = 'KIDNAPPING' AND description LIKE '%CHILD%';
# Out:
#    sqlite:///ChicagoCensusData.db
#  * sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [(5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %%
# %sql SELECT * FROM ChicagoCrimeData WHERE primary_type = 'KIDNAPPING' AND description LIKE '%CHILD%';
# Out:
#    sqlite:///ChicagoCensusData.db
#  * sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [(5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %%
# %sql SELECT DISTINCT primary_type FROM ChicagoCrimeData WHERE location_description LIKE '%SCHOOL%';
# Out:
#    sqlite:///ChicagoCensusData.db
#  * sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %%
# %sql SELECT "Elementary, Middle, or High School", AVG(safety_score) FROM ChicagoPublicSchools GROUP BY "Elementary, Middle, or High School";
# Out:
#    sqlite:///ChicagoCensusData.db
#  * sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# (sqlite3.OperationalError) no such table: ChicagoPublicSchools
# [SQL: SELECT "Elementary, Middle, or High School" , AVG(safety_score) FROM ChicagoPublicSchools GROUP BY "Elementary, Middle, or High School" ;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql sqlite:///ChicagoPublicSchools.db

# %%
# %sql SELECT "Elementary, Middle, or High School", AVG(safety_score) FROM ChicagoPublicSchools GROUP BY "Elementary, Middle, or High School";
# Out:
#    sqlite:///ChicagoCensusData.db
#    sqlite:///ChicagoCrimeData.db
#  * sqlite:///ChicagoPublicSchools.db
# Done.
# [('ES', 49.52038369304557), ('HS', 49.62352941176471), ('MS', 48.0)]

# %%
# %sql sqlite:///ChicagoCensusData.db

# %%
# %sql SELECT community_area_name, percent_households_below_poverty FROM ChicagoCensusData ORDER BY percent_households_below_poverty DESC LIMIT 5;
# Out:
#  * sqlite:///ChicagoCensusData.db
#    sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %%
# %sql SELECT community_area_name FROM ChicagoCensusData WHERE hardship_index = (SELECT MAX(hardship_index) FROM ChicagoCensusData);
# Out:
#  * sqlite:///ChicagoCensusData.db
#    sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [('Riverdale',)]

# %%
# %sql SELECT community_area_name FROM ChicagoCensusData WHERE community_area_number = (SELECT community_area_number FROM ChicagoCrimeData GROUP BY community_area_number ORDER BY COUNT(case_number) DESC LIMIT 1);
# Out:
#  * sqlite:///ChicagoCensusData.db
#    sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# (sqlite3.OperationalError) no such table: ChicagoCrimeData
# [SQL: SELECT community_area_name FROM ChicagoCensusData WHERE community_area_number = (SELECT community_area_number FROM ChicagoCrimeData GROUP BY community_area_number ORDER BY COUNT(case_number) DESC LIMIT 1);]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql sqlite:///ChicagoCrimeData.db

# %%
# %sql SELECT community_area_number FROM ChicagoCrimeData GROUP BY community_area_number ORDER BY COUNT(*) DESC LIMIT 1;
# Out:
#    sqlite:///ChicagoCensusData.db
#  * sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [(25.0,)]

# %%
# %sql sqlite:///ChicagoCensusData.db

# %%
# %sql SELECT community_area_name FROM ChicagoCensusData WHERE community_area_number = 25;
# Out:
#  * sqlite:///ChicagoCensusData.db
#    sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [('Austin',)]

# %%
# %sql sqlite:///ChicagoCrimeData.db

# %%
# %sql SELECT community_area_number FROM ChicagoCrimeData GROUP BY community_area_number ORDER BY COUNT(*) DESC LIMIT 1;
# Out:
#    sqlite:///ChicagoCensusData.db
#  * sqlite:///ChicagoCrimeData.db
#    sqlite:///ChicagoPublicSchools.db
# Done.
# [(25.0,)]
